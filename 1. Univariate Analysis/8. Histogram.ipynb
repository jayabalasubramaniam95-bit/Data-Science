# %%
import pandas as pd
import numpy as np
import warnings as ws
ws.filterwarnings('ignore')

# %%
dataset= pd.read_csv('Placement.csv')
from UnivariateLib import Univariate
quan, quali = Univariate.fnQuanQuali(dataset)
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive = pd.DataFrame(index=["Mean", "Median", "Mode", "Q1:25%", "Q2:50%", "Q3:75%","Max", "IQR", "1.5Rule","Lesser","Greater","Min","Max","Skew","Kurtosis"], columns=quan)
descriptive
# Out:
#          sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q1:25%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q2:50%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q3:75%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Max        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# IQR        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# 1.5Rule    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Lesser     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Greater    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Min        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Max        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Skew       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Kurtosis   NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
from UnivariateLib import Univariate
descriptive = Univariate.fnCentralDedency(quan, dataset)

# %%
lesser =[]
greater =[]
from UnivariateLib import Univariate
lesser, greater= Univariate.fnfindOutlier(quan, descriptive);

# %%
lesser
# Out:
# ['hsc_p']

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
from UnivariateLib import Univariate
dataset= Univariate.fnReplaceOutlier(lesser, greater, dataset,descriptive)

# %%
lesser
# Out:
# ['hsc_p']

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
from UnivariateLib import Univariate
descriptive = Univariate.fnCentralDedency(quan, dataset)

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# Max         215       89.4      91.15       88.5       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5Rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# Min           1      40.89      42.75       50.0       50.0      51.21
# Max         215       89.4      91.15       88.5       98.0      77.89
# Skew        0.0  -0.132649   0.162611   0.204164   0.282308   0.313576
# Kurtosis   -1.2   -0.60751   0.086901   -0.09749   -1.08858  -0.470723
#
#                  salary
# Mean      277648.648649
# Median         265000.0
# Mode           300000.0
# Q1:25%         240000.0
# Q2:50%         265000.0
# Q3:75%         300000.0
# Max            390000.0
# IQR             60000.0
# 1.5Rule         90000.0
# Lesser         150000.0
# Greater        390000.0
# Min            200000.0
# Max            390000.0
# Skew             0.8067
# Kurtosis      -0.239837

# %%
import seaborn as sns
import matplotlib.pyplot as plt

col = "ssc_p"  # change to any column name

plt.figure(figsize=(7,5))
sns.histplot(descriptive[col], kde=True, bins=15, color="steelblue")
plt.title(f"{col} | Skew={descriptive[col].skew():.2f} | Kurtosis={descriptive[col].kurt():.2f}")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

col = "ssc_p"  # change to any column name

plt.figure(figsize=(7,5))
sns.histplot(descriptive[col], kde=True, bins=15, color="steelblue")
plt.title(f"{col} | Skew={descriptive[col].skew():.2f} ")
plt.show()

# %%
lesser =[]
greater =[]
from UnivariateLib import Univariate
lesser, greater= Univariate.fnfindOutlier(quan, descriptive);

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
from UnivariateLib import Univariate
freqTable = Univariate.fnfreTable("ssc_p", dataset)
freqTable
# Out:
#      Values  Frequency  Relative Frequency  Cusum Frequency
# 0     62.00         11            0.106796         0.106796
# 1     63.00         10            0.097087         0.203883
# 2     67.00          9            0.087379         0.291262
# 3     52.00          9            0.087379         0.378641
# 4     73.00          9            0.087379         0.466019
# ..      ...        ...                 ...              ...
# 98    69.70          1            0.009709         2.048544
# 99    80.92          1            0.009709         2.058252
# 100   83.00          1            0.009709         2.067961
# 101   86.50          1            0.009709         2.077670
# 102   80.60          1            0.009709         2.087379
#
# [103 rows x 4 columns]
